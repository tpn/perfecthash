# %%
def get_entry(i):
    return f"""
    ENTRY(BestGraph{i+1}_Attempt,                                              \\
          Context->BestGraphInfo[{i}].Attempt,                               \\
          OUTPUT_INT)                                                      \\
                                                                           \\
    ENTRY(BestGraph{i+1}_ElapsedMilliseconds,                                  \\
          Context->BestGraphInfo[{i}].ElapsedMilliseconds,                   \\
          OUTPUT_INT)                                                      \\
                                                                           \\
    ENTRY(BestGraph{i+1}_Value,                                                \\
          Context->BestGraphInfo[{i}].Value,                                 \\
          OUTPUT_INT)                                                      \\
                                                                           \\
    ENTRY(BestGraph{i+1}_EqualCount,                                           \\
          Context->BestGraphInfo[{i}].EqualCount,                            \\
          OUTPUT_INT)                                                      \\
    """

# %%
#cb(cb().replace('0', '{i}').replace('1', '{i+1}').replace('\\', '\\\\'))

# %%
from tpn.clipboard import *

# %%
lines = [ get_entry(i) for i in range(0, 32) ]

# %%
output = ' \\'.join(lines)

# %%
cb(output)
# Out:
# copied 37362 characters into clipboard...
# ...
